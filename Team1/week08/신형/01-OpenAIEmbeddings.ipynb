# %% [markdown]
# # OpenAIEmbeddings
#
# 문서 임베딩은 문서의 내용을 수치적인 벡터로 변환하는 과정입니다.
#
# 이 과정을 통해 문서의 의미를 수치화하고, 다양한 자연어 처리 작업에 활용할 수 있습니다. 대표적인 사전 학습된 언어 모델로는 BERT와 GPT가 있으며, 이러한 모델들은 문맥적 정보를 포착하여 문서의 의미를 인코딩합니다.
#
# 문서 임베딩은 토큰화된 문서를 모델에 입력하여 임베딩 벡터를 생성하고, 이를 평균하여 전체 문서의 벡터를 생성합니다. 이 벡터는 문서 분류, 감성 분석, 문서 간 유사도 계산 등에 활용될 수 있습니다.
#
# [더 알아보기](https://platform.openai.com/docs/guides/embeddings/embedding-models)

# %% [markdown]
# ## 설정
#
# 먼저 langchain-openai를 설치하고 필요한 환경 변수를 설정합니다.

# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("CH08-Embeddings")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH08-Embeddings

# %% [markdown]
# 지원되는 모델 목록
#
# | MODEL                  | PAGES PER DOLLAR | PERFORMANCE ON MTEB EVAL | MAX INPUT |
# |------------------------|------------------|---------------------------|-----------|
# | text-embedding-3-small | 62,500           | 62.3%                     | 8191      |
# | text-embedding-3-large | 9,615            | 64.6%                     | 8191      |
# | text-embedding-ada-002 | 12,500           | 61.0%                     | 8191      |

# %%
from langchain_openai import OpenAIEmbeddings

# OpenAI의 "text-embedding-3-small" 모델을 사용하여 임베딩을 생성합니다.
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_openai import OpenAIEmbeddings
#       3 # OpenAI의 "text-embedding-3-small" 모델을 사용하여 임베딩을 생성합니다.
#       4 embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
#
# File ~/Library/Caches/pypoetry/virtualenvs/langchain-kr-s6hO_3vk-py3.11/lib/python3.11/site-packages/langchain_openai/__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~/Library/Caches/pypoetry/virtualenvs/langchain-kr-s6hO_3vk-py3.11/lib/python3.11/site-packages/langchain_openai/chat_models/__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~/Library/Caches/pypoetry/virtualenvs/langchain-kr-s6hO_3vk-py3.11/lib/python3.11/site-packages/langchain_openai/chat_models/azure.py:11
#       8 from typing import Any, Literal, TypeAlias, TypeVar
#      10 import openai
# ---> 11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#      13 from langchain_core.outputs import ChatGenerationChunk, ChatResult
#
# ImportError: cannot import name 'LanguageModelInput' from 'langchain_core.language_models' (/Users/shinhyung/Library/Caches/pypoetry/virtualenvs/langchain-kr-s6hO_3vk-py3.11/lib/python3.11/site-packages/langchain_core/language_models/__init__.py)

# %%
text = "임베딩 테스트를 하기 위한 샘플 문장입니다."

# %% [markdown]
# ## 쿼리 임베딩

# %% [markdown]
# `embeddings.embed_query(text)`는 주어진 텍스트를 임베딩 벡터로 변환하는 함수입니다.
#
# 이 함수는 텍스트를 벡터 공간에 매핑하여 의미적으로 유사한 텍스트를 찾거나 텍스트 간의 유사도를 계산하는 데 사용될 수 있습니다.

# %%
# 텍스트를 임베딩하여 쿼리 결과를 생성합니다.
query_result = embeddings.embed_query(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 텍스트를 임베딩하여 쿼리 결과를 생성합니다.
# ----> 2 query_result = embeddings.embed_query(text)
#
# NameError: name 'embeddings' is not defined

# %% [markdown]
# `query_result[:5]`는 `query_result` 리스트의 처음 5개 요소를 슬라이싱(slicing)하여 선택합니다.

# %%
# 쿼리 결과의 처음 5개 항목을 선택합니다.
query_result[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 쿼리 결과의 처음 5개 항목을 선택합니다.
# ----> 2 query_result[:5]
#
# NameError: name 'query_result' is not defined

# %% [markdown]
# ## Document 임베딩

# %% [markdown]
# `embeddings.embed_documents()` 함수를 사용하여 텍스트 문서를 임베딩합니다.
#
# - `[text]`를 인자로 전달하여 단일 문서를 리스트 형태로 임베딩 함수에 전달합니다.
# - 함수 호출 결과로 반환된 임베딩 벡터를 `doc_result` 변수에 할당합니다.

# %%
doc_result = embeddings.embed_documents(
    [text, text, text, text]
)  # 텍스트를 임베딩하여 문서 벡터를 생성합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 doc_result = embeddings.embed_documents(
#       2     [text, text, text, text]
#       3 )  # 텍스트를 임베딩하여 문서 벡터를 생성합니다.
#
# NameError: name 'embeddings' is not defined

# %% [markdown]
# `doc_result[0][:5]`는 `doc_result` 리스트의 첫 번째 요소에서 처음 5개의 문자를 슬라이싱하여 선택합니다.

# %%
len(doc_result)  # 문서 벡터의 길이를 확인합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(doc_result)  # 문서 벡터의 길이를 확인합니다.
#
# NameError: name 'doc_result' is not defined

# %%
# 문서 결과의 첫 번째 요소에서 처음 5개 항목을 선택합니다.
doc_result[0][:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # 문서 결과의 첫 번째 요소에서 처음 5개 항목을 선택합니다.
# ----> 2 doc_result[0][:5]
#
# NameError: name 'doc_result' is not defined

# %% [markdown]
# ## 차원 지정
#
# `text-embedding-3` 모델 클래스를 사용하면 반환되는 임베딩의 크기를 지정할 수 있습니다.
#
# 예를 들어, 기본적으로 `text-embedding-3-small`는 1536 차원의 임베딩을 반환합니다.

# %%
# 문서 결과의 첫 번째 요소의 길이를 반환합니다.
len(doc_result[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 문서 결과의 첫 번째 요소의 길이를 반환합니다.
# ----> 2 len(doc_result[0])
#
# NameError: name 'doc_result' is not defined

# %% [markdown]
# ### 차원(dimensions) 조정
#
# 하지만 `dimensions=1024`를 전달함으로써 임베딩의 크기를 1024로 줄일 수 있습니다.

# %%
# OpenAI의 "text-embedding-3-small" 모델을 사용하여 1024차원의 임베딩을 생성하는 객체를 초기화합니다.
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-small", dimensions=1024)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # OpenAI의 "text-embedding-3-small" 모델을 사용하여 1024차원의 임베딩을 생성하는 객체를 초기화합니다.
# ----> 2 embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-small", dimensions=1024)
#
# NameError: name 'OpenAIEmbeddings' is not defined

# %%
# 주어진 텍스트를 임베딩하고 첫 번째 임베딩 벡터의 길이를 반환합니다.
len(embeddings_1024.embed_documents([text])[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 주어진 텍스트를 임베딩하고 첫 번째 임베딩 벡터의 길이를 반환합니다.
# ----> 2 len(embeddings_1024.embed_documents([text])[0])
#
# NameError: name 'embeddings_1024' is not defined

# %% [markdown]
# ## 유사도 계산

# %%
sentence1 = "안녕하세요? 반갑습니다."
sentence2 = "안녕하세요? 반갑습니다!"
sentence3 = "안녕하세요? 만나서 반가워요."
sentence4 = "Hi, nice to meet you."
sentence5 = "I like to eat apples."

# %%
from sklearn.metrics.pairwise import cosine_similarity

sentences = [sentence1, sentence2, sentence3, sentence4, sentence5]
embedded_sentences = embeddings_1024.embed_documents(sentences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from sklearn.metrics.pairwise import cosine_similarity
#       3 sentences = [sentence1, sentence2, sentence3, sentence4, sentence5]
# ----> 4 embedded_sentences = embeddings_1024.embed_documents(sentences)
#
# NameError: name 'embeddings_1024' is not defined

# %%
def similarity(a, b):
    return cosine_similarity([a], [b])[0][0]

# %%
# sentence1 = "안녕하세요? 반갑습니다."
# sentence2 = "안녕하세요? 만나서 반가워요."
# sentence3 = "Hi, nice to meet you."
# sentence4 = "I like to eat apples."

for i, sentence in enumerate(embedded_sentences):
    for j, other_sentence in enumerate(embedded_sentences):
        if i < j:
            print(
                f"[유사도 {similarity(sentence, other_sentence):.4f}] {sentences[i]} \t <=====> \t {sentences[j]}"
            )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 # sentence1 = "안녕하세요? 반갑습니다."
#       2 # sentence2 = "안녕하세요? 만나서 반가워요."
#       3 # sentence3 = "Hi, nice to meet you."
#       4 # sentence4 = "I like to eat apples."
# ----> 6 for i, sentence in enumerate(embedded_sentences):
#       7     for j, other_sentence in enumerate(embedded_sentences):
#       8         if i < j:
#
# NameError: name 'embedded_sentences' is not defined
